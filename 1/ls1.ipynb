# %% [markdown]
# # Основы клиент-серверного взаимодействия. Парсинг API

# %% [markdown]
# ## Задание 1
# Посмотреть документацию к API GitHub, разобраться как вывести список репозиториев для конкретного пользователя, сохранить JSON-вывод в файле *.json.

# %%
import requests
import json

# %%
service = 'https://api.github.com'
user = 'mwaskom'
response = requests.get(f'{service}/users/{user}/repos')

with open('github.json', 'w', encoding='utf-8') as a:
    json.dump(response.json(), a, ensure_ascii=False)

for i in response.json():
    print(i['name'])
# Out:
# ActflowToolbox
# annotmpl
# cogneuro_categories
# connexplore
# context_dots
# cregg
# delsacc
# dots
# Fluid_NiPype
# GAPE_Experiment
# ipython
# lyman
# mapalign
# matplotlib
# monitor_calibration
# moss
# mpld3
# mwaskom.github.io
# nbci
# neuropythy
# neurosynth
# nibabel
# nipy
# nipype
# nipype_concepts
# nitime
# optlearner
# pandas
# PM
# popeye

# %% [markdown]
# ## Задание 2
# Изучить список открытых API. Найти среди них любое, требующее авторизацию (любого типа). Выполнить запросы к нему, пройдя авторизацию. Ответ сервера записать в файл.

# %%
url = 'https://api.thecatapi.com/v1/images/search'
api_key = '17d94b92-754f-46eb-99a0-65be65b5d18f'
headers = {
    'Content-Type': 'application/json', \
    'x-api-key': api_key
}

# %%
cat_response = requests.get(f'{url}', headers = headers)

with open('cat.json', 'w', encoding='utf-8') as a:
    json.dump(cat_response.json(), a, ensure_ascii=False)

print(cat_response.json())
# Out:
# [{'breeds': [], 'id': 'MjA4MDU4Nw', 'url': 'https://cdn2.thecatapi.com/images/MjA4MDU4Nw.jpg', 'width': 550, 'height': 365, 'pending': 0, 'approved': 1, 'rejected': 0}]
